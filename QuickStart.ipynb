# %% [markdown]
# <a href="https://colab.research.google.com/github/rajabhupati/AI-Session/blob/main/QuickStart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Create an Account** -
# https://huggingface.co/

# %% [markdown]
# # **Generating the Hugging face token using the following Instructions**
#
#
# 1.   Go to settings as shown below
# 2.   Create access token

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **For Lab Purpose ,Create Access Token **
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Model Usage Access**
# For certain models, you may need to request and ensure your token is granted access to enable the model's usage.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
